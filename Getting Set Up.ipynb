# %% [markdown]
# # Getting Set Up
#
# Welcome to the Quantum Computing Workshop! This notebook will guide you through the essential setup steps.
#
# ---
#
# ## Prerequisites
#
# Before we begin, ensure you have the following installed:
# - **Python 3.11** (via pyenv)
# - **pip** (Python package manager)
# - **Virtual Environment** support
#
# ---
#
# ## Installation Steps
#
# ### Step 1: Create Virtual Environment
# ```bash
# "$(pyenv prefix 3.11.10)/bin/python" -m venv .venv
# source .venv/bin/activate
# ```
#
# ### Step 2: Install Qiskit & Dependencies
# Run the following commands to install all required packages:

# %%
# ========== CORE QUANTUM COMPUTING PACKAGES ==========

# Qiskit with Visualization
# Installs Qiskit 2.3.1, the main quantum computing framework by IBM
# [visualization] extra includes tools for visualizing quantum circuits
# !pip install --upgrade qiskit[visualization]==2.3.1

# Qiskit Aer
# High-performance quantum circuit simulator
# Supports statevector, unitary, and other simulation methods
# !pip install --upgrade qiskit_aer

# Qiskit IBM Runtime
# Access to IBM's cloud-based quantum processors and simulators
# !pip install --upgrade qiskit_ibm_runtime

# ========== VISUALIZATION & UTILITIES ==========

# Matplotlib
# Essential plotting library for visualizing quantum results and data
# !pip install --upgrade matplotlib

# PyLaTeXenc
# LaTeX rendering for professional quantum circuit diagrams
# !pip install --upgrade pylatexenc

# Prototype ZNE
# Zero Noise Extrapolation for improving quantum algorithm accuracy on NISQ devices
# !pip install --upgrade prototype-zne
# Out:
# ...
#   Using cached qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# ...
#   Using cached rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# ...
#   Using cached numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached matplotlib-3.10.8-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# ...
#   Using cached pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached pillow-12.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...
#   Using cached pylatexenc-2.10-py3-none-any.whl
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...

# %%
# ========== DOWNLOAD HELPER MODULES ==========

# Download Workshop Helper Files
print("Downloading helper modules...")
# !wget -O quantum_grader.py 'https://raw.githubusercontent.com/ahkatlio/BRAC-University-quantum-information/main/quantum_grader.py'
# !wget -O HiddenCode.py 'https://raw.githubusercontent.com/ahkatlio/BRAC-University-quantum-information/main/HiddenCode.py'
print("Helper modules downloaded successfully!")
# Out:
# ...
# --2026-03-18 21:54:23--  https://raw.githubusercontent.com/ahkatlio/BRAC-University-quantum-information/main/quantum_grader.py
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7086 (6.9K) [text/plain]
# Saving to: ‘quantum_grader.py’
#
# quantum_grader.py   100%[===================>]   6.92K  --.-KB/s    in 0s
#
# 2026-03-18 21:54:24 (28.9 MB/s) - ‘quantum_grader.py’ saved [7086/7086]
#
# --2026-03-18 21:54:24--  https://raw.githubusercontent.com/ahkatlio/BRAC-University-quantum-information/main/HiddenCode.py
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# ...

# %%
# ========== IMPORT GRADING UTILITIES ==========

print("Loading workshop grading utilities...")
from quantum_grader import (
    check_homework_1, 
    check_homework_2, 
    check_homework_3, 
    grade_homework_5, 
    grade_homework_6, 
    grade_homework_7_qc, 
    grade_homework_7_matrix, 
    grade_homework_8, 
    grade_homework_9, 
    oracle_box
)
print("All utilities loaded successfully!")
# Out:
# Loading workshop grading utilities...
# All utilities loaded successfully!

# %% [markdown]
# ---
#
# ## Verification
#
# Let's verify that **Qiskit** is properly installed and working:

# %%
# ========== SYSTEM CHECK ==========

import sys

print("=" * 60)
print("SYSTEM VERIFICATION".center(60))
print("=" * 60)

try:
    import qiskit
    print(f"[OK] Qiskit Version:           {qiskit.__version__}")
except ImportError:
    print("[ERROR] Qiskit is not installed!")

try:
    import qiskit_aer
    print(f"[OK] Qiskit Aer:               Installed")
except ImportError:
    print("[ERROR] Qiskit Aer is not installed!")

try:
    import matplotlib
    print(f"[OK] Matplotlib:               Installed")
except ImportError:
    print("[ERROR] Matplotlib is not installed!")

print(f"[OK] Python Version:           {sys.version.split()[0]}")
print("=" * 60)
print("Setup complete! You're ready to explore quantum computing.")
print("=" * 60)
# Out:
# ...
#                     SYSTEM VERIFICATION
# ...
# [OK] Qiskit Version:           2.3.1
# [OK] Qiskit Aer:               Installed
# [OK] Matplotlib:               Installed
# [OK] Python Version:           3.11.10
# ...
# Setup complete! You're ready to explore quantum computing.
# ...
