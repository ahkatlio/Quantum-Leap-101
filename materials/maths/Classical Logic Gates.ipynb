# %% [markdown]
# # Reviewing Classical Logical Gates
# In classical computing, logical gates are the fundamental building blocks that perform basic logical functions on one or more binary inputs to produce a single binary output. These gates are essential for processing and manipulating data in digital circuits. The most common classical logic gates include:
#
# <p align="center">
# <table>
#   <thead>
#     <tr>
#       <th>Gate</th>
#       <th>Operation Details</th>
#       <th>Input</th>
#       <th>Output</th>
#       <th>Graphical Representation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Buffer</td>
#       <td>Outputs the same value as the input</td>
#       <td>
#         <table>
#           <tr><th>A</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>Q</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/Buffer_ANSI_Labelled.svg.png" alt="Buffer Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>NOT</td>
#       <td>Inverts the input value</td>
#       <td>
#         <table>
#           <tr><th>A</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>Q</th></tr>
#           <tr><td>1</td></tr>
#           <tr><td>0</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/NOT_ANSI_Labelled.svg.png" alt="NOT Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>AND</td>
#       <td>Outputs true if both inputs are true</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>A ∧ B = Q</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/AND_ANSI_Labelled.svg.png" alt="AND Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>OR</td>
#       <td>Outputs true if at least one input is true</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>A ∨ B = Q</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/OR_ANSI_Labelled.svg.png" alt="OR Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>XOR</td>
#       <td>Outputs true if inputs are different</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>A ⊕ B = Q</th></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>0</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/XOR_ANSI_Labelled.svg.png" alt="XOR Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>NAND</td>
#       <td>Outputs true if at least one input is false</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>¬(A ∧ B) = Q</th></tr>
#           <tr><td>1</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>1</td></tr>
#           <tr><td>0</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/NAND_ANSI_Labelled.svg.png" alt="NAND Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>NOR</td>
#       <td>Outputs true if both inputs are false</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>¬(A ∨ B) = Q</th></tr>
#           <tr><td>1</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>0</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/NOR_ANSI_Labelled.svg.png" alt="NOR Gate" width="150"></td>
#     </tr>
#     <tr>
#       <td>XNOR</td>
#       <td>Outputs true if inputs are the same</td>
#       <td>
#         <table>
#           <tr><th>A</th><th>B</th></tr>
#           <tr><td>0</td><td>0</td></tr>
#           <tr><td>0</td><td>1</td></tr>
#           <tr><td>1</td><td>0</td></tr>
#           <tr><td>1</td><td>1</td></tr>
#         </table>
#       </td>
#       <td>
#         <table>
#           <tr><th>¬(A ⊕ B) = Q</th></tr>
#           <tr><td>1</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>0</td></tr>
#           <tr><td>1</td></tr>
#         </table>
#       </td>
#       <td><img src="Classical Logic Gates/XNOR_ANSI_Labelled.svg.png" alt="XNOR Gate" width="150"></td>
#     </tr>
#   </tbody>
# </table>
# </p>

# %% [markdown]
# <p align="center" style="margin-top: 40px;">
#   <a href="Bloch Sphere.ipynb" style="
#     display: inline-block;
#     padding: 12px 24px;
#     background: linear-gradient(135deg, #4F46E5, #6366F1);
#     color: white;
#     text-decoration: none;
#     border-radius: 10px;
#     font-weight: bold;
#     letter-spacing: 0.2px;
#     border: 1px solid rgba(255,255,255,0.18);
#     box-shadow: 0 6px 16px rgba(79, 70, 229, 0.35);
#     transition: all 0.3s ease;
#   "
#   onmouseover="this.style.background='linear-gradient(135deg, #4338CA, #4F46E5)'; this.style.transform='translateY(-2px)'; this.style.boxShadow='0 10px 20px rgba(79, 70, 229, 0.45)';"
#   onmouseout="this.style.background='linear-gradient(135deg, #4F46E5, #6366F1)'; this.style.transform='translateY(0)'; this.style.boxShadow='0 6px 16px rgba(79, 70, 229, 0.35)';"
# >
#   ← Bloch Sphere
# </a>
#     &nbsp;&nbsp;&nbsp;&nbsp;
# <a href="Classical Logic Gates.ipynb" style="
#     display: inline-block;
#     padding: 12px 24px;
#     background: linear-gradient(135deg, #4F46E5, #6366F1);
#     color: white;
#     text-decoration: none;
#     border-radius: 10px;
#     font-weight: bold;
#     letter-spacing: 0.2px;
#     border: 1px solid rgba(255,255,255,0.18);
#     box-shadow: 0 6px 16px rgba(79, 70, 229, 0.35);
#     transition: all 0.3s ease;
#   "
#   onmouseover="this.style.background='linear-gradient(135deg, #4338CA, #4F46E5)'; this.style.transform='translateY(-2px)'; this.style.boxShadow='0 10px 20px rgba(79, 70, 229, 0.45)';"
#   onmouseout="this.style.background='linear-gradient(135deg, #4F46E5, #6366F1)'; this.style.transform='translateY(0)'; this.style.boxShadow='0 6px 16px rgba(79, 70, 229, 0.35)';"
# >
#    Classical Logic Gates →
# </a>
# </p>
